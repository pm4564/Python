# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dabest

# %%
df = pd.read_csv("/Users/Myers/Desktop/Jupyter/geo_split_plates.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of            G    N   geo    h2o        OI   epf
# 0    CantonS  5.0   5.0   21.0 -0.615385   5.2
# 1    CantonS  5.0  10.0  121.0 -0.847328  26.2
# 2    CantonS  5.0  21.0   38.0 -0.288136  11.8
# 3    CantonS  5.0   3.0   64.0 -0.910448  13.4
# 4    CantonS  5.0   2.0   58.0 -0.933333  12.0
# ..       ...  ...   ...    ...       ...   ...
# 146      NaN  NaN   NaN    NaN       NaN   NaN
# 147      NaN  NaN   NaN    NaN       NaN   NaN
# 148      NaN  NaN   NaN    NaN       NaN   NaN
# 149      NaN  NaN   NaN    NaN       NaN   NaN
# 150      NaN  NaN   NaN    NaN       NaN   NaN
#
# [151 rows x 6 columns]>

# %%
sns.catplot(x = "G", y="OI", data=df, alpha = .5)

# %%
olf = pd.read_csv("/Users/Myers/Desktop/Jupyter/olfactogenetic_titration.csv")

# %%
olf.head
# Out:
# <bound method NDFrame.head of                         G  N  geo  h2o        OI   epf    conc comments  date
# 0                 CantonS  5    5   21 -0.615385   5.2   10_3'      NaN   NaN
# 1                 CantonS  5   10  121 -0.847328  26.2   10_3'      NaN   NaN
# 2                 CantonS  5   21   38 -0.288136  11.8   10_3'      NaN   NaN
# 3                 CantonS  5    3   64 -0.910448  13.4   10_3'      NaN   NaN
# 4                 CantonS  5    2   58 -0.933333  12.0   10_3'      NaN   NaN
# ..                    ... ..  ...  ...       ...   ...     ...      ...   ...
# 103  Or49a-GAL4/UAS-Or56a  5   52   39  0.142857  18.2  10_12'      NaN   NaN
# 104  Or49a-GAL4/UAS-Or56a  5   21   15  0.166667   7.2  10_12'      NaN   NaN
# 105  Or49a-GAL4/UAS-Or56a  5   16   12  0.142857   5.6  10_12'      NaN   NaN
# 106  Or49a-GAL4/UAS-Or56a  5   34   19  0.283019  10.6  10_12'      NaN   NaN
# 107  Or49a-GAL4/UAS-Or56a  5   13   30 -0.395349   8.6  10_12'      NaN   NaN
#
# ...

# %%
sns.catplot(x = "conc", y = "OI", hue = "G", data=olf)

# %%
g = sns.FacetGrid(olf, col = "conc")
g.map(sns.swarmplot, "G", "OI",  palette = ["b", "r"], alpha = .5)

# %%
g = sns.relplot(x="G", y="OI",
                 col="conc", hue="G",
                 kind="scatter", data=olf)

# %% [markdown]
# You can see above the different ways me might plot this. I favour the facetgrid swarmplot, but still haven't figured out how to add colour (hue) as well, maybe in the swarmplot argument? Nope. Use Palette!
#
# That's all worked nicely, but now want to be able to apply some statistical tests to all this. Will start with dabest (https://github.com/ACCLAB/DABEST-python; tutorial: https://acclab.github.io/DABEST-python-docs/tutorial.html), then move on to hypothesis testing if we think we need it.

# %%
geo = pd.read_csv("/Users/Myers/Desktop/Jupyter/geo_split_plates.csv")
geo_dabest = dabest.load(data=geo, x="G", y="OI",
                          idx=("CantonS", "L1983/TNT", "57807/UAS-TNT"), resamples=5000)
geo_dabest
# Out:
# DABEST v0.3.0
# ...
#
# Good morning!
# The current time is Thu Mar 12 11:40:43 2020.
#
# Effect size(s) with 95% confidence intervals will be computed for:
# 1. L1983/TNT minus CantonS
# 2. 57807/UAS-TNT minus CantonS
#
# 5000 resamples will be used to generate the effect size bootstraps.

# %%
geo_dabest.mean_diff.plot();
# Out:
# /Users/Myers/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Can we use dabest on the olfactogenetic plot with multiple grids? Not sure how we might do this...

# %%
sk.learn, __version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ff71f234cb9b> in <module>
# ----> 1 sk.learn, __version__
#
# NameError: name 'sk' is not defined

# %%
import sklearn

# %%
sklearn,__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b3205f560983> in <module>
# ----> 1 sklearn,__version__
#
# NameError: name '__version__' is not defined

# %%
sklearn.__version__
# Out:
# '0.23.1'
