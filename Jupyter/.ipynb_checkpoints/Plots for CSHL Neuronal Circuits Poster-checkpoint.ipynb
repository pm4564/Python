# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dabest

# %%
paavo = pd.read_csv("/Users/Myers/Desktop/Jupyter/CSHL_neuronal_circuits_poster/DA2_edited.csv")

# %%
paavo = pd.read_csv("/Users/Myers/Desktop/Jupyter/CSHL_neuronal_circuits_poster/DA2_edited.csv")
paavo.head
# Out:
# <bound method NDFrame.head of             geno    PI order
# 0     85E04/TNT+ -0.35     a
# 1     85E04/TNT+ -0.38     a
# 2     85E04/TNT+ -0.96     a
# 3     85E04/TNT+  0.26     a
# 4     85E04/TNT+  0.24     a
# ..           ...   ...   ...
# 147       TNT+/+ -0.93     d
# 148       TNT+/+ -0.75     d
# 149       TNT+/+ -0.69     d
# 150       TNT+/+ -1.00     d
# 151       TNT+/+  0.96     d
#
# [152 rows x 3 columns]>

# %%
sns.catplot(x = "geno", y="PI", data=paavo, alpha = .5)

# %%
paavo = pd.read_csv("/Users/Myers/Desktop/Jupyter/CSHL_neuronal_circuits_poster/DA2_edited.csv")

# %%
paavo.head
# Out:
# <bound method NDFrame.head of          geno    PI order
# 0    DA2/TNT+ -0.35     a
# 1    DA2/TNT+ -0.38     a
# 2    DA2/TNT+ -0.96     a
# 3    DA2/TNT+  0.26     a
# 4    DA2/TNT+  0.24     a
# ..        ...   ...   ...
# 147    TNT+/+ -0.93     d
# 148    TNT+/+ -0.75     d
# 149    TNT+/+ -0.69     d
# 150    TNT+/+ -1.00     d
# 151    TNT+/+  0.96     d
#
# [152 rows x 3 columns]>

# %%
paavo_dabest = dabest.load(data = paavo, x="geno", y="PI",
                          idx = ("DA2/TNT+", "DA2/TNT-", "DA2/+", "TNT+/+"), resamples=5000)

# %%
paavo_dabest
# Out:
# DABEST v0.3.0
# ...
#
# Good afternoon!
# The current time is Mon Mar 16 17:31:13 2020.
#
# Effect size(s) with 95% confidence intervals will be computed for:
# 1. DA2/TNT- minus DA2/TNT+
# 2. DA2/+ minus DA2/TNT+
# 3. TNT+/+ minus DA2/TNT+
#
# 5000 resamples will be used to generate the effect size bootstraps.

# %%
fig_1 = paavo_dabest.mean_diff.plot();
# Out:
# /Users/Myers/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig_1.savefig("fig_1.png")
# Out:
# /Users/Myers/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Now let's do the next two figures...

# %%
paavo2 = pd.read_csv("/Users/Myers/Desktop/Jupyter/CSHL_neuronal_circuits_poster/L728_TNT_edited.csv")

# %%
paavo2.head
# Out:
# <bound method NDFrame.head of            geno    PI
# 0    AV1a1/TNT+  0.69
# 1    AV1a1/TNT+ -0.43
# 2    AV1a1/TNT+ -0.52
# 3    AV1a1/TNT+  0.40
# 4    AV1a1/TNT+  0.93
# ..          ...   ...
# 147      TNT+/+ -0.48
# 148      TNT+/+ -0.23
# 149      TNT+/+ -0.63
# 150      TNT+/+ -0.32
# 151      TNT+/+ -0.92
#
# [152 rows x 2 columns]>

# %%
paavo2_dabest = dabest.load(data = paavo2, x="geno", y="PI",
                          idx = ("AV1a1/TNT+", "AV1a1/TNT-", "AV1a1/+", "TNT+/+"), resamples=5000)

# %%
paavo2_dabest
# Out:
# DABEST v0.3.0
# ...
#
# Good afternoon!
# The current time is Mon Mar 16 17:55:29 2020.
#
# Effect size(s) with 95% confidence intervals will be computed for:
# 1. AV1a1/TNT- minus AV1a1/TNT+
# 2. AV1a1/+ minus AV1a1/TNT+
# 3. TNT+/+ minus AV1a1/TNT+
#
# 5000 resamples will be used to generate the effect size bootstraps.

# %%
fig_2 = paavo2_dabest.mean_diff.plot();
# Out:
# /Users/Myers/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig_2.savefig("fig_2.png")
# Out:
# /Users/Myers/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   """Entry point for launching an IPython kernel.

# %%
DN  = pd.read_csv("/Users/Myers/Desktop/Jupyter/CSHL_neuronal_circuits_poster/DN_TNT.csv")

# %%
DN.head
# Out:
# <bound method NDFrame.head of              G  N  geo  h2o        PI   epf
# 0   DNp42/TNT+  5   12   18 -0.200000   6.0
# 1   DNp42/TNT+  5   18   17  0.028571   7.0
# 2   DNp42/TNT+  5   12   16 -0.142857   5.6
# 3   DNp42/TNT+  5   60   55  0.043478  23.0
# 4   DNp42/TNT+  5   15   35 -0.400000  10.0
# ..         ... ..  ...  ...       ...   ...
# 69      TNT+/+  5   15   88 -0.708738  20.6
# 70      TNT+/+  5   19   48 -0.432836  13.4
# 71      TNT+/+  5   27   78 -0.485714  21.0
# 72      TNT+/+  5   47   68 -0.182609  23.0
# 73      TNT+/+  5   28  142 -0.670588  34.0
#
# [74 rows x 6 columns]>

# %%
DN_dabest = dabest.load(data = DN, x="G", y="PI",
                          idx = ("DNp42/TNT+", "DNp42/TNT-", "DNp42/+", "TNT+/+"), resamples=5000)

# %%
DN_dabest
# Out:
# DABEST v0.3.0
# ...
#
# Good evening!
# The current time is Mon Mar 16 19:00:09 2020.
#
# Effect size(s) with 95% confidence intervals will be computed for:
# 1. DNp42/TNT- minus DNp42/TNT+
# 2. DNp42/+ minus DNp42/TNT+
# 3. TNT+/+ minus DNp42/TNT+
#
# 5000 resamples will be used to generate the effect size bootstraps.

# %%
fig_3 = DN_dabest.mean_diff.plot();
# Out:
# /Users/Myers/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig_3.savefig("fig_3.png")
# Out:
# /Users/Myers/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   """Entry point for launching an IPython kernel.
